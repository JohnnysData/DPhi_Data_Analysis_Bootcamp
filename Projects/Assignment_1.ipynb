# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\johny\Desktop\DHPi\Week_1\Standard Metropolitan Areas Data.csv")

# %%
df.head()
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# 2       50.6      2066.3   33216       1       41.32
# 3       52.2      1966.7   32906       2       67.38
# 4       66.1      1514.5   26573       4       80.19

# %%
area = df["land_area"]

# %%
#Question3
area.mean()
# Out:
# 2615.7272727272725

# %%
#Question3
crime_rate = df["crime_rate"]

# %%
#Question3
crime_rate.max ()
# Out:
# 85.62

# %%
#Question3
min_income = df["income"]

# %%
#Question3
min_income.min()
# Out:
# 769

# %%
#Question3
df.notnull().sum()
# Out:
# land_area         99
# percent_city      99
# percent_senior    99
# physicians        99
# hospital_beds     99
# graduates         99
# work_force        99
# income            99
# region            99
# crime_rate        99
# dtype: int64

# %%
#Question3
region = df["region"]

# %%
#Question3
region.mode()
# Out:
# 0    3
# dtype: int64

# %%
#Question3
region.max()
# Out:
# 4

# %%
#Question4
df.corr()
# Out:
#                 land_area  percent_city  percent_senior  physicians  \
# land_area        1.000000     -0.077320        0.092226    0.085054
# percent_city    -0.077320      1.000000       -0.250995    0.067391
# percent_senior   0.092226     -0.250995        1.000000    0.056454
# physicians       0.085054      0.067391        0.056454    1.000000
# hospital_beds    0.081034      0.052898        0.083775    0.974241
# graduates        0.088728      0.076720       -0.155695    0.049500
# work_force       0.135792      0.016011        0.035240    0.965597
# income           0.111404      0.019235        0.046073    0.976209
# region           0.292392      0.235880       -0.242811   -0.140961
# crime_rate       0.293907      0.159596       -0.177992    0.187763
#
#                 hospital_beds  graduates  work_force    income    region  \
# land_area            0.081034   0.088728    0.135792  0.111404  0.292392
# ...

# %%
#Question3
crime_rate.mean()
# Out:
# 55.64303030303031

# %%
#Question3
df["region"].value_counts()
# Out:
# 3    36
# 2    25
# 1    21
# 4    17
# Name: region, dtype: int64

# %%
#Question5
region4 = df[df["region"] == 4]
region4.head()
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 4        2480          31.5            10.5        8502          16751
# 13        782          28.4             7.8        3119           8656
# 14       4226          38.1             9.8        3285           5392
# 18      27293          25.3            12.3        2018           6323
# 20       9155          53.8            11.1        2280           6450
#
#     graduates  work_force  income  region  crime_rate
# 4        66.1      1514.5   26573       4       80.19
# 13       70.5       915.2   12591       4       63.20
# 14       67.8       699.8   10918       4       64.05
# 18       57.4       510.6    7399       4       76.03
# 20       60.1       575.2    7766       4       85.62

# %%
#Question6
df[(df["region"] == 4) & (df["crime_rate"] == 55.64)]
# Out:
# Empty DataFrame
# Columns: [land_area, percent_city, percent_senior, physicians, hospital_beds, graduates, work_force, income, region, crime_rate]
# Index: []

# %%
#Question6
df[(df["region"] == 1) & (df["crime_rate"] >= 54.16)]
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 10       1008          16.6            10.3        4006          16704
# 24       2966          26.9            10.3        2053           6604
# 55        192          60.5            10.8         617           1789
#
#     graduates  work_force  income  region  crime_rate
# 0        50.1      4083.9   72100       1       75.55
# 10       55.9       935.5   15953       1       54.16
# 24       56.3       450.4    6966       1       56.55
# 55       44.1       212.6    3158       1       58.79

# %%
df[(df["crime_rate"] ==85.62) & (df["region"] ==4)]
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 20       9155          53.8            11.1        2280           6450
#
#     graduates  work_force  income  region  crime_rate
# 20       60.1       575.2    7766       4       85.62

# %%
df[(df["region"] == 3) | (df["land_area"] >= 5000)]
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 5        2815          23.1             6.7        7340          16941
# 6        8360          46.3             8.2        4047          14347
# 7        6794          60.1             6.3        4562          14333
# 12       4326          23.6             7.3        3064           9976
# 16       2045          37.2            21.4        1949           8863
# 18      27293          25.3            12.3        2018           6323
# 20       9155          53.8            11.1        2280           6450
# 22       1967          51.1             8.8        2520           8467
# 26       1392          37.2             9.8        1579           6087
# 27       3358          35.1            11.3        1649           5512
# 30       3214          47.7             9.4        1285           3459
# 31       3491          48.5             9.7        1496           5620
# ...

# %%
#Question7

import matplotlib.pyplot as plt

line_plot = plt.plot(df.land_area, df.crime_rate)

plt.show()

# %%
#Question8

plt.scatter(df.hospital_beds, df.physicians)
plt.xlabel("Hospital Beds")
plt.ylabel("Physicians")
plt.title("Physicians vs Hospital Beds")
plt.show()

# %%
#Question8

import seaborn as sns

#sns.scatterplot(x='hospital_beds', y='physicians', data=df)
#plt.show()

# %%
sns.scatterplot(x ="hospital_beds", y = "physicians", data = df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-903f649b6f78> in <module>()
# ----> 1 sns.scatterplot(x ="hospital_beds", y = "physicians", data = df)
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'

# %%
# !pip install -U seaborn
# Out:
# ...
# Requirement not upgraded as not directly required: matplotlib>=2.1.2 in c:\users\johny\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement not upgraded as not directly required: scipy>=1.0.1 in c:\users\johny\anaconda3\lib\site-packages (from seaborn) (1.1.0)
# Requirement not upgraded as not directly required: numpy>=1.13.3 in c:\users\johny\anaconda3\lib\site-packages (from seaborn) (1.14.3)
# Requirement not upgraded as not directly required: pandas>=0.22.0 in c:\users\johny\anaconda3\lib\site-packages (from seaborn) (0.23.0)
# Requirement not upgraded as not directly required: cycler>=0.10 in c:\users\johny\anaconda3\lib\site-packages (from matplotlib>=2.1.2->seaborn) (0.10.0)
# Requirement not upgraded as not directly required: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\johny\anaconda3\lib\site-packages (from matplotlib>=2.1.2->seaborn) (2.2.0)
# ...

# %%
python -m pip install --upgrade pip
# Out:
#   File "<ipython-input-89-0a8cf7b99133>", line 1
#     python -m pip install --upgrade pip
#                 ^
# SyntaxError: invalid syntax

# %%
sns.scatterplot(x ="hospital_beds", y = "physicians", data = df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-903f649b6f78> in <module>()
# ----> 1 sns.scatterplot(x ="hospital_beds", y = "physicians", data = df)
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'

# %%
sns.barplot(df.region, df.index)
plt.show()

# %%
plt.hist(df.income)
plt.xlabel("Income")
plt.ylabel("Frequency")
plt.title("Total Income")
plt.show()
